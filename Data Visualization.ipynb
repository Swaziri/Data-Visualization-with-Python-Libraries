# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\MSWaziri\\Desktop\\heart.csv")

# %%
data.head()
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0  40.0   M           ATA        140        289.0        0.0     Normal
# 1  49.0   F           NAP        160        180.0        0.0     Normal
# 2  37.0   M           ATA        130        283.0        0.0         ST
# 3  48.0   F           ASY        138        214.0        0.0     Normal
# 4  54.0   M           NAP        150        195.0        0.0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0  172.0              N      0.0       Up           0.0
# 1  156.0              N      1.0     Flat           1.0
# 2   98.0              N      0.0       Up           0.0
# 3  108.0              Y      1.5     Flat           1.0
# 4  122.0              N      0.0       Up           0.0

# %%
data['HeartDisease'].replace({1:'yes',0:'No'}, inplace=True)

# %%
sns.countplot(x = "HeartDisease", data=data)
plt.xlabel("HeartDisease")
plt.ylabel("Frequency")
plt.title("Bar Chart of Heart Disease")
plt.show()

# %% [markdown]
# This shows that the percentage of people with heart disease is higher than those without the disease in the dataset

# %%
sns.countplot(x = "Sex", data=data)
plt.xlabel("Sex")
plt.ylabel("Frequency")
plt.title("Bar Chart of Sex")
plt.show()

# %%
sns.set_palette("bright")
with sns.axes_style(style='white'):
    g = sns.catplot("Sex", col ="HeartDisease", col_wrap=3, data=data, kind="count", height = 5.0, aspect=0.80, palette=["Green", "Purple"])
# Out:
# C:\Users\MSWaziri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# This shows that the percentage of male gender is higher than female gender in the dataset

# %%
sns.countplot(x = "ChestPainType", data=data)
plt.xlabel("ChestPainType Distribution")
plt.ylabel("Frequency")
plt.title("Bar Chart of ChestPainType")
plt.show()

# %% [markdown]
# This shows that the percentage of people with ASY chestpain is higher than those with ATA, NAP and TA in the dataset

# %%
sns.histplot(data=data['RestingBP'], bins=10)
# Out:
# <AxesSubplot:xlabel='RestingBP', ylabel='Count'>

# %% [markdown]
# This shows that the percentage of people with 125 restingBP is higher in the dataset

# %%
sns.histplot(data=data['Cholesterol'], bins=10)
# Out:
# <AxesSubplot:xlabel='Cholesterol', ylabel='Count'>

# %% [markdown]
# This shows that the percentage of people with 200-300 Cholesterol level is higher in the dataset

# %%
sns.histplot(data=data['FastingBS'], bins=10)
# Out:
# <AxesSubplot:xlabel='FastingBS', ylabel='Count'>

# %% [markdown]
# This shows that the percentage of people with 0 FastingBS is higher in the dataset

# %%
sns.countplot(x = "RestingECG", data=data)
plt.xlabel("RestingECG")
plt.ylabel("Frequency")
plt.title("Bar Chart of RestingECG")
plt.show()

# %% [markdown]
# This shows that the percentage of people with normal RestingECG is higher in the dataset

# %%
sns.histplot(data=data['MaxHR'], bins=10)
# Out:
# <AxesSubplot:xlabel='MaxHR', ylabel='Count'>

# %% [markdown]
# This shows that the percentage of people with MaxHR of 120-140 is higher in the dataset

# %%
sns.countplot(x = "ExerciseAngina", data=data)
plt.xlabel("ExerciseAngina")
plt.ylabel("Frequency")
plt.title("Bar Chart of ExerciseAngina")
plt.show()

# %% [markdown]
# This shows that the percentage of people with ExerciseAngina No is higher in the dataset

# %%
sns.histplot(data=data['Oldpeak'], bins=10)
# Out:
# <AxesSubplot:xlabel='Oldpeak', ylabel='Count'>

# %% [markdown]
# This shows that the percentage of people with Oldpeak of -1 - 0  is higher in the dataset

# %%
sns.countplot(x = "ST_Slope", data=data)
plt.xlabel("ST_Slope")
plt.ylabel("Frequency")
plt.title("Bar Chart of ST_Slope")
plt.show()

# %% [markdown]
# This shows that the percentage of people with ST_Slope "flat" is higher in the dataset

# %%
data['HeartDisease'].replace({'yes':1,'No':0}, inplace=True)

# %%
sns.barplot(x='Sex', y='HeartDisease', data=data,ci=None)
plt.xlabel("Sex")
plt.ylabel("HeartDisease")
plt.title("Bar Chart of Sex and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# This shows that male gender have higher percentage of heart disease in the dataset

# %%
data['Age'] = pd.cut(data['Age'], bins = 6, labels=['20-30','31-40','41-50','51-60','61-70','71-80'])
sns.barplot(x='Age', y='HeartDisease', data=data,ci=None)
plt.xlabel("Age")
plt.ylabel("HeartDisease")
plt.title("Age Group and HeartDisease")
plt.show()

# %% [markdown]
# This shows that age group of 61-70 and 71-80 have higher percentage of heart disease

# %%
sns.barplot(x='ChestPainType', y='HeartDisease', data=data,ci=None)
plt.xlabel("ChestPainType")
plt.ylabel("HeartDisease")
plt.title("Bar Chart of ChestPainType and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# This shows that people with ASY chestpain have higher percentage of heart disease

# %%
sns.regplot(x='RestingBP', y='HeartDisease', data=data)
plt.xlabel("RestingBP")
plt.ylabel("HeartDisease")
plt.title("Scatter Chart of RestingBP and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# This shows that there is no any relationship between RestingBP and heart disease

# %%
sns.regplot(x='FastingBS', y='HeartDisease', data=data)
plt.xlabel("FastingBS")
plt.ylabel("HeartDisease")
plt.title("Scatter Chart of FastingBS and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# This shows that there is no any relationship between FastingBS and heart disease

# %%
sns.barplot(x='RestingECG', y='HeartDisease', data=data, ci =None)
plt.xlabel("RestingECG")
plt.ylabel("HeartDisease")
plt.title("Bar Chart of RestingECG and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %% [raw]
# This shows that of people with ST restingECG have higher percentage of heart disease

# %%
sns.regplot(x='MaxHR', y='HeartDisease', data=data, ci =None)
plt.xlabel("MaxHR")
plt.ylabel("HeartDisease")
plt.title("Scatter Chart of MaxHR and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# This shows that there is no any relationship between MaxHR and heart disease

# %%
sns.barplot(x='ExerciseAngina', y='HeartDisease', data=data, ci =None)
plt.xlabel("ExerciseAngina")
plt.ylabel("HeartDisease")
plt.title("Bar Chart of ExerciseAngina and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# This shows that people with Y ExerciseAngina have higher percentage of heart disease

# %%
sns.regplot(x='Oldpeak', y='HeartDisease', data=data)
plt.xlabel("Oldpeak")
plt.ylabel("HeartDisease")
plt.title("Scatter Chart of Oldpeak and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# This shows that there is no any relationship between Oldpeak and heart disease

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='ST_Slope', y='HeartDisease', data=data, ci=None)
plt.xlabel("ST_Slope")
plt.ylabel("HeartDisease")
plt.title("Bar Chart of ST_Slope and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# This shows that people with flat ST_Slope have higher percentage of heart disease

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This shows that the data from cholesterol have many outliers

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=data['RestingBP'], y=data['HeartDisease'])
plt.xlabel("RestingBP")
plt.ylabel("HeartDisease")
plt.title("Bar Chart of RestingBP and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %%
sns.regplot(x='Oldpeak', y='Oldpeak', data=data, ci=None)
plt.xlabel("ST_Slope")
plt.ylabel("HeartDisease")
plt.title("Bar Chart of Oldpeak and HeartDisease")
plt.xticks(rotation=0)
plt.show()

# %%
data['Sex'].replace({'M':1,'F':0}, inplace=True)
data['ChestPainType'].replace({'ATA':1,'NAP':1,'ASY':3,'TA':4}, inplace=True)
data['RestingECG'].replace({'Normal':1,'ST':2,'LVH':3}, inplace=True)
data['ExerciseAngina'].replace({'Y':1,'N':0}, inplace=True)
data['ST_Slope'].replace({'Up':1,'Flat':0}, inplace=True)
data.head()
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0  31-40  1.0            1.0        140        289.0        0.0         1.0
# 1  41-50  0.0            1.0        160        180.0        0.0         1.0
# 2  31-40  1.0            1.0        130        283.0        0.0         2.0
# 3  41-50  0.0            3.0        138        214.0        0.0         1.0
# 4  51-60  1.0            1.0        150        195.0        0.0         1.0
#
#    MaxHR  ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0  172.0             0.0      0.0        1           0.0
# 1  156.0             0.0      1.0        0           1.0
# 2   98.0             0.0      0.0        1           0.0
# 3  108.0             1.0      1.5        0           1.0
# 4  122.0             0.0      0.0        1           0.0

# %%
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
#                      Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# Sex             1.000000       0.172468   0.008713    -0.200092   0.120076
# ChestPainType   0.172468       1.000000   0.071986    -0.103853   0.141636
# RestingBP       0.008713       0.071986   1.000000     0.091636   0.068506
# Cholesterol    -0.200092      -0.103853   0.091636     1.000000  -0.260974
# FastingBS       0.120076       0.141636   0.068506    -0.260974   1.000000
# RestingECG     -0.018343       0.085294   0.095433     0.112095   0.050707
# MaxHR          -0.189186      -0.275298  -0.110544     0.235792  -0.131438
# ExerciseAngina  0.190664       0.329194   0.154001    -0.034166   0.060451
# Oldpeak         0.105734       0.286631   0.173287     0.050148   0.052698
# HeartDisease    0.305445       0.457500   0.116612    -0.232741   0.267291
#
#                 RestingECG     MaxHR  ExerciseAngina   Oldpeak  HeartDisease
# ...

# %%
import numpy as np
from scipy import stats
data = np.array([4,5,1,2,7,2,6,9,3])
# Calculate Mean
dt_mean = np.mean(data) ; print ("Mean :",round(dt_mean,9))
# Calculate Median
dt_median = np.median(data) ; print ("Median :",dt_median)
# Calculate Mode
dt_mode = stats.mode(data); 
print ("Mode :",dt_mode[0][0])
# Out:
# Mean : 4.333333333
# Median : 4.0
# Mode : 2
